# %%
import pandas as pd

# %%
df = pd.read_csv("codage_Loris Rousseau - Retranscription.csv")

# %%
df
# Out:
#      Thème                        Code  \
# 0      NaN                        Code
# 1      NaN                         ---
# 2      NaN             1. Introduction
# 3      NaN  2. Objectif de l'entretien
# 4      NaN     3. Durée de l'entretien
# ..     ...                         ...
# 175    NaN                         3.6
# 176    NaN                         3.7
# 177    NaN                         3.8
# 178    NaN                         3.9
# 179    NaN                        3.10
#
#                                               Verbatim
# 0                                           Verbatim |
# 1                                                --- |
# 2    "Donc j'ai démarré l’enregistrement maintenant...
# 3    "L'entretien va se faire en 6 parties différen...
# 4    "Normalement l'entretien devrait se faire entr...
# ..                                                 ...
# 175  "Les enseignants devraient être prudents dans ...
# ...
